# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
df = pd.read_csv("Hw2.2.csv")

# %% [markdown]
# ## Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %% [markdown]
# ## Визначте розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (8704, 25)

# %% [markdown]
# ## Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# ## Порахуйте, яка частка пропусків міститься в кожній колонці

# %%
df.isnull().sum() / len(df) * 100
# Out:
# N                                    0.000000
# Посада                               0.000000
# Мова програмування                  44.232537
# Спеціалізація                       82.938879
# Загальний досвід роботи              0.000000
# Досвід роботи на поточному місці     0.000000
# Зарплата на місяць                   0.000000
# Зміна зарплати за 12 місяців         0.000000
# Місто                                0.000000
# Розмір компанії                      0.000000
# Тип компанії                         0.000000
# Стать                                0.000000
# Вік                                  0.000000
# Освіта                               0.000000
# Університет                          4.113051
# Ще студент                           0.000000
# Рівень англійської                   0.000000
# Предметна область                    2.562040
# Дата заповнення                      0.000000
# User.Agent                           0.000000
# ...

# %% [markdown]
# ## Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
df1 = df.drop(["Спеціалізація", "Університет", "Предметна область", "Валюта", "cls"], axis=1)
df1
# Out:
#          N                    Посада Мова програмування  \
# 0        1        Junior QA engineer                NaN
# 1        2        Junior QA engineer                NaN
# 2        3         Software Engineer            C#/.NET
# 3        4         Software Engineer         JavaScript
# 4        5  Senior Software Engineer         JavaScript
# ...    ...                       ...                ...
# 8699  8700               QA engineer                NaN
# 8700  8701                 Marketing                NaN
# 8701  8702  Junior Software Engineer         Ruby/Rails
# 8702  8703                 Team lead                NaN
# 8703  8704  Senior Software Engineer               Java
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# 1            менше 3 місяців                  менше 3 місяців
# 2                          4                                1
# ...

# %% [markdown]
# ## Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
df1.isnull().sum() / len(df1) * 100
# Out:
# N                                    0.000000
# Посада                               0.000000
# Мова програмування                  44.232537
# Загальний досвід роботи              0.000000
# Досвід роботи на поточному місці     0.000000
# Зарплата на місяць                   0.000000
# Зміна зарплати за 12 місяців         0.000000
# Місто                                0.000000
# Розмір компанії                      0.000000
# Тип компанії                         0.000000
# Стать                                0.000000
# Вік                                  0.000000
# Освіта                               0.000000
# Ще студент                           0.000000
# Рівень англійської                   0.000000
# Дата заповнення                      0.000000
# User.Agent                           0.000000
# exp                                  0.000000
# current_job_exp                      0.000000
# salary                               0.000000
# dtype: float64

# %% [markdown]
# ## Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df1 = df1.dropna()
df1.isnull().sum() / len(df1) * 100
# Out:
# N                                   0.0
# Посада                              0.0
# Мова програмування                  0.0
# Загальний досвід роботи             0.0
# Досвід роботи на поточному місці    0.0
# Зарплата на місяць                  0.0
# Зміна зарплати за 12 місяців        0.0
# Місто                               0.0
# Розмір компанії                     0.0
# Тип компанії                        0.0
# Стать                               0.0
# Вік                                 0.0
# Освіта                              0.0
# Ще студент                          0.0
# Рівень англійської                  0.0
# Дата заповнення                     0.0
# User.Agent                          0.0
# exp                                 0.0
# current_job_exp                     0.0
# salary                              0.0
# dtype: float64

# %% [markdown]
# ## df1.isnull().sum() / len(df1) * 100

# %%
df1.shape
# Out:
# (4854, 20)

# %% [markdown]
# ## Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df1[df1["Мова програмування"] == "Python"]
python_data.head()
# Out:
#        N                    Посада Мова програмування Загальний досвід роботи  \
# 12    13         Software Engineer             Python                       1
# 68    69         Software Engineer             Python                     1.5
# 87    88  Junior Software Engineer             Python                     0.5
# 114  115  Junior Software Engineer             Python                     1.5
# 143  144  Junior Software Engineer             Python                       1
#
#     Досвід роботи на поточному місці  Зарплата на місяць  \
# 12                   менше 3 місяців                 800
# 68                               0.5                 900
# 87                               0.5                 600
# 114                              0.5                 685
# 143                                1                 750
#
#      Зміна зарплати за 12 місяців Місто Розмір компанії   Тип компанії  \
# 12                            200  Київ      до 50 осіб  Аутсорсингова
# ...

# %% [markdown]
# ## Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# ## Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
grouped_python_data = python_data.groupby("Посада")
min_max_python_data = grouped_python_data["Зарплата на місяць"].agg(["min", "max"]).reset_index()
min_max_python_data
# Out:
#                      Посада   min   max
# 0  Junior Software Engineer   100  1250
# 1  Senior Software Engineer  1300  9200
# 2         Software Engineer   500  5400
# 3          System Architect  3000  5000
# 4            Technical Lead  1425  6200

# %% [markdown]
# ## Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
def fill_avg_salary(data):
    return data.mean()

# %% [markdown]
# ## Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
avg_python_data = grouped_python_data["Зарплата на місяць"].apply(fill_avg_salary).reset_index(name="avg")
avg_python_data
# Out:
#                      Посада          avg
# 0  Junior Software Engineer   560.841270
# 1  Senior Software Engineer  3387.096774
# 2         Software Engineer  1799.070000
# 3          System Architect  4000.000000
# 4            Technical Lead  3165.909091

# %% [markdown]
# ## Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
avg_stats = avg_python_data["avg"].describe()
avg_stats
# Out:
# count       5.000000
# mean     2582.583427
# std      1387.255829
# min       560.841270
# 25%      1799.070000
# 50%      3165.909091
# 75%      3387.096774
# max      4000.000000
# Name: avg, dtype: float64

# %% [markdown]
# ## Збережіть отриману таблицю в CSV файл

# %%
avg_stats_df = avg_stats.to_frame(name="avg_stats")
avg_stats_df.to_csv("Hw2.2_avg_stats.csv", index=True)

# %% [markdown]
# ## Візуалізація

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Тип компанії", y="Зарплата на місяць", data=df1, hue="Тип компанії")
plt.title("Середня зарплата за типом компанії")
plt.xlabel("Тип компанії")
plt.ylabel("Середня зарплата на місяць")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="exp", y="salary", data=df1, hue="Місто", palette="viridis", style="Стать")
plt.title("Досвід роботи vs Зарплата")
plt.xlabel("Досвід роботи (роки)")
plt.ylabel("'Зарплата на місяць")
plt.legend(title="Місто та Стать")
plt.show()

# %%
sns.countplot(x="Освіта", data=df, hue="Освіта", palette="Set2")
plt.title("Кількість людей за рівнем освіти")
plt.xlabel("Освіта")
plt.ylabel("Кількість")
plt.xticks(rotation=45)
plt.show()
